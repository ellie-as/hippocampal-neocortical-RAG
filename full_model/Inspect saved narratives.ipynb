# %%
import pickle, textwrap
from pathlib import Path

pkl_path = Path("output/data/recalled_stories.pkl")

with pkl_path.open("rb") as f:
    artefact = pickle.load(f)

stories = artefact["recalled_stories"]
details = artefact.get("details_used", {})

variants = [
    ("IMAGINED",  "imagined"),
    ("GIST-0",             0),
    ("+1",                 1),
    ("+3",                 3),
    ("FULL",       "full"),
]

wrap = lambda s: textwrap.fill(s, 90, subsequent_indent=" " * 11)

for idx, orig in enumerate(stories["full"][0:5]):
    divider = f"\n==== STORY {idx} {'='*60}"
    print(divider)
    print("ORIGINAL :", wrap(orig))

    for tag, key in variants:
        txt = stories[key][idx]
        print(f"{tag:<10}: {wrap(txt)}")

        # show the cue-phrases, if stored in the pickle
        if key in (1, 3) and key in details:
            cues = details[key][idx]
            if cues:                         # non-empty?
                cue_str = ";  ".join(cues)
                print(f"{'':<10}  ↳ details_used: {cue_str}")

print("\nDone. Total stories:", len(stories['full']))
# Out:
# ==== STORY 0 ============================================================
# ORIGINAL : Susan really likes to have coffee in the morning and drinks it daily. One morning Susan
#            realized she was out and had to go buy more. She found a store nearby that had
#            a special coffee blend. She was so excited when she brewed her new coffee.
#            After brewing her coffee she took a sip and sighed happily.
# IMAGINED  : [INST] Susan really likes to have coffee in the morning and drinks it daily. What happened
#            (in detail)? [/INST] Susan is an individual who has developed a daily habit of
#            enjoying a cup of coffee in the morning. This routine likely begins as soon as
#            she wakes up, signifying the start of her day. Here's a detailed description of
#            what might happen:  1. Alarm goes off: The first thing Susan does in the
#            morning is to wake up from her sleep. Her alarm clock goes off, signaling the
#            end of her night's rest. She might snooze the
# GIST-0    : Susan enjoys having coffee in the morning and drinks it daily. She went to the grocery
#            store to buy coffee and found a new brand that she had not tried before. She
#            was excited to try it and bought it. When she got home, she brewed a cup of
#            coffee using the new brand and enjoyed it very much. She was happy that she
#            found a new coffee brand that she liked and would continue to buy it.
# +1        : Susan found a new coffee shop nearby that had a special coffee blend that she really
#            enjoyed. She went there every morning to buy a cup of coffee and started her
#            day with it. The coffee shop was conveniently located, and she appreciated the
#            friendly staff and the cozy atmosphere. The coffee was rich and flavorful, and
#            she looked forward to it every day. She was happy to have found a new routine
#            that made her mornings more enjoyable.
# +3        : Susan found a new coffee shop nearby that had a special coffee blend that she really
#            enjoyed. She went to the shop every day to buy a cup of coffee. One day, she
#            ran out of coffee at home and realized she didn't have any more to buy. She was
#            so excited when she finally went to the shop and bought a new bag of the
#            special coffee blend. She was thrilled to brew her coffee the next morning with
#            her new purchase.
# FULL      : Susan really likes to have coffee in the morning and drinks it daily. One morning Susan
#            realized she was out and had to go buy more. She found a store nearby that had
#            a special coffee blend. She was so excited when she brewed her new coffee.
#            After brewing her coffee she took a sip and sighed happily.
#
# ==== STORY 1 ============================================================
# ORIGINAL : Tanya had just turned sixteen. Her mom would never let her dye her hair before she was
#            this old. She already knew what color she wanted and everything. Yet at the
#            last moment she had her doubts. She decided to give her own natural hair color
#            a chance.
# IMAGINED  : [INST] Tanya had just turned sixteen. What happened (in detail)? [/INST] Tanya's sixteenth
#            birthday was a significant milestone in her life, marking her entry into young
#            adulthood. Here's a detailed description of what might have happened on her
#            special day:  1. Waking up: Tanya woke up early in the morning, feeling a mix
#            of excitement and nervousness about turning sixteen. She opened her eyes to the
#            sound of her alarm clock and looked around her room, taking in the familiar
#            sights of her posters,
# GIST-0    : Tanya had just turned sixteen. She wanted to dye her hair purple, but her mother didn't
#            want her to. Tanya was very upset about it, but eventually she decided to wait
#            until she was eighteen to dye her hair. She didn't want to disobey her mother
#            and risk losing her trust. Tanya's mother eventually came around and let her
#            dye her hair a few months later, when Tanya was almost eighteen. Tanya was very
#            happy and
# +1        : Tanya had just turned sixteen. She had been wanting to dye her hair for a long time, but
#            her mom had always refused, saying that she was too young. Tanya had saved up
#            her money and finally decided to go to the salon and get her hair dyed without
#            her mom's permission. She was nervous and excited at the same time, but she
#            knew that she wanted to do it. She went to the salon and chose a deep red
#            color. The stylist
# +3        : Tanya had just turned sixteen. She had always wanted to dye her hair, but her mom had
#            always forbidden her to do so until she was older. Tanya decided to give her
#            natural hair color a chance and let it grow out. However, on the day of her
#            sixteenth birthday, she had doubts and almost went through with dyeing it. In
#            the end, she decided to wait a little longer and see how she felt about her
#            natural hair color. She didn't
# FULL      : Tanya had just turned sixteen. Her mom would never let her dye her hair before she was
#            this old. She already knew what color she wanted and everything. Yet at the
#            last moment she had her doubts. She decided to give her own natural hair color
#            a chance.
#
# ==== STORY 2 ============================================================
# ORIGINAL : Trent's father took him to a large parking lot for driving lessons. His father's expensive
#            car had a manual transmission. Trent had difficulty learning to use the clutch
#            and accelerator. He became frustrated, and accidentally drove the car over a
#            curb. His dad decided to teach Trent to drive using his mother's car.
# IMAGINED  : [INST] Trent's father took him to a large parking lot for driving lessons. What happened
#            (in detail)? [/INST] Trent's father took him to a large, open parking lot for
#            driving lessons, likely with the intention of providing him with a safe and
#            controlled environment to practice driving skills and gain confidence behind
#            the wheel. Here's a detailed description of what might have happened during
#            their driving lesson:  1. Preparation: Before starting the lesson, Trent's
#            father ensured that they had all the necessary items for the driving lesson,
#            such as a valid driver's permit or lear
# GIST-0    : Trent's father took him to a large parking lot for driving lessons. Trent was nervous and
#            had trouble controlling the car. He kept stalling the car and his father became
#            frustrated. Trent's father decided to switch to an automatic transmission car,
#            which Trent was able to drive more easily. Trent was relieved and grateful for
#            his father's patience and understanding.
# +1        : Trent's father took him to a large parking lot for driving lessons. Trent's father decided
#            to teach Trent to drive using his mother's car. Trent was nervous and made a
#            mistake by accidentally putting the car in reverse instead of drive. The car
#            moved backward and hit a curb, causing the tire to go flat. Trent's father was
#            angry and frustrated, but eventually calmed down and continued teaching Trent
#            to drive. Trent learned to control the
# +3        : Trent's father took him to a large parking lot for driving lessons. Trent's father decided
#            to teach Trent to drive using his mother's car. Trent was nervous and made
#            several mistakes. He accidentally drove the car over a curb. Trent's father
#            became frustrated and stopped the lesson. Trent's father then took him to a
#            driving school to continue his lessons.
# FULL      : Trent's father took him to a large parking lot for driving lessons. His father's expensive
#            car had a manual transmission. Trent had difficulty learning to use the clutch
#            and accelerator. He became frustrated, and accidentally drove the car over a
#            curb. His dad decided to teach Trent to drive using his mother's car.
#
# ==== STORY 3 ============================================================
# ORIGINAL : Travis was driving along a road at night. He saw a woman in a white gown walking along the
#            road. Travis stopped and offered her a ride. The woman got into the car without
#            a word. Travis then informed her she couldn't smoke in the car.
# IMAGINED  : [INST] Travis was driving along a road at night. What happened (in detail)? [/INST] Travis
#            was driving along a quiet, two-lane road, the kind where the only sounds you
#            could hear were the gentle hum of his car engine and the occasional crickets
#            chirping in the distance. The moon was full and bright, casting long, dancing
#            shadows on the pavement as he drove. He had the radio turned off, preferring
#            the silence to the static and chatter that filled the airwaves.  As he drove,
#            he kept a careful eye on the
# GIST-0    : Travis was driving along a road at night when he saw a woman in a white dress standing on
#            the side of the road. He stopped the car and offered her a ride. She got in and
#            they started talking. She told him that she had been in a car accident and her
#            boyfriend had left her there. She asked him to take her to the nearest gas
#            station. He agreed and they drove to the gas station. She got out of the car
#            and thanked him for the ride. He
# +1        : Travis was driving along a road at night when he picked up a hitchhiker, a woman. She
#            asked for a cigarette and Travis informed her she couldn't smoke in the car.
#            The woman then asked for a ride to the next town. Travis agreed and they
#            continued driving. The woman then asked for a drink of water and Travis stopped
#            at a gas station to get her a bottle. As they were driving again, the woman
#            asked Travis if he wanted to have
# +3        : Travis was driving along a road at night. He saw a woman in a white gown walking along the
#            road. He stopped the car and offered her a ride. She accepted and got in the
#            car. Travis then informed her she couldn't smoke in the car. She lit a
#            cigarette and he asked her to put it out. She refused and he became angry. She
#            then asked him why he stopped for her and he told her he didn't want to hit her
#            with his car.
# FULL      : Travis was driving along a road at night. He saw a woman in a white gown walking along the
#            road. Travis stopped and offered her a ride. The woman got into the car without
#            a word. Travis then informed her she couldn't smoke in the car.
#
# ==== STORY 4 ============================================================
# ORIGINAL : The log floated on the river. A man tried to sit on it. It rolled over. The man tried to
#            get back on it. The log kept spinning in the man's grip.
# IMAGINED  : [INST] The log floated on the river. What happened (in detail)? [/INST] To provide a
#            detailed answer to your question, I would need more context. Here's a possible
#            scenario based on the given information:  A log, which is a large, heavy piece
#            of wood, was floating on a river. The log could have ended up in the river from
#            various sources. It might have been carried away by the river current after
#            falling from the bank during heavy rain or flooding. Alternatively, it could
#            have been deliberately placed in the river by someone for various reasons
# GIST-0    : The log floated on the river. The man tried to grab it with a stick, but the log rolled
#            away. The man tried to grab it with his hands, but the log was too slippery.
#            The man tried to grab it with a rope, but the log was too heavy. The man tried
#            to grab it with a net, but the log was too big. The man tried to grab it with a
#            boat, but the log was too fast. The man gave up and sat
# +1        : The man sat on the log, but it floated away, and he fell into the water. The man tried to
#            grab the log again, but it floated away again. The man tried to swim after the
#            log, but it floated too fast. The man gave up and watched the log float away.
# +3        : The man tried to sit on the log, but it kept spinning in his grip. He tried to hold on,
#            but the log rolled over, and he fell in the water.
# FULL      : The log floated on the river. A man tried to sit on it. It rolled over. The man tried to
#            get back on it. The log kept spinning in the man's grip.
#
# Done. Total stories: 500

# %%
import pickle, textwrap
from pathlib import Path

DATA_DIR = Path("output/data")

enc_path  = DATA_DIR / "recalled_stories.pkl"
con_path  = DATA_DIR / "consolidation_recall.pkl"

forg_path = DATA_DIR / "forgetting_multi.pkl"

enc  = pickle.load(open(enc_path, "rb"))

con  = pickle.load(open(con_path, "rb")) if con_path.exists() else None
forg = pickle.load(open(forg_path, "rb")) if forg_path.exists() else None

orig_list   = enc["recalled_stories"]["full"]
rec_variants = enc["recalled_stories"]          # dict: imagined/0/1/3/full
con_epochs   = con["epoch_recalls"] if con else []   # list[epoch][story]
forg_recs    = []

if forg:
    eps = forg.get("recalls")
    if eps and isinstance(eps[0], str):
        eps = [eps]
    forg_recs = eps or []

wrap = lambda s: textwrap.fill(s, 100, subsequent_indent=" " * 12)

# print everything
for idx, orig in enumerate(orig_list[0:5]):
    hdr = f" STORY {idx} ".center(90, "=")
    print(hdr)
    print("ORIGINAL :", wrap(orig))

    # baseline recalls
    for tag, key in [("IMAGINED", "imagined"),
                     ("GIST-0",            0),
                     ("+1",                1),
                     ("+3",                3),
                     ("FULL",     "full")]:
        print(f"{tag:<10}: {wrap(rec_variants[key][idx])}")

    # consolidation epochs
    if con_epochs:
        print("\n-- CONSOLIDATION ---------------------------------------------")
        for e, epoch in enumerate(con_epochs, start=1):
            print(f"Epoch {e:02d}: {wrap(epoch[idx])}")

    #forgetting episodes
    if forg_recs:
        print("\n-- FORGETTING -----------------------------------------------")
        for ep, episode in enumerate(forg_recs):
            print(f"Episode {ep:02d}: {wrap(episode[idx])}")

print("\nDone. Total stories printed:", len(orig_list))
# Out:
# ======================================== STORY 0 =========================================
# ORIGINAL : Susan really likes to have coffee in the morning and drinks it daily. One morning Susan realized she
#             was out and had to go buy more. She found a store nearby that had a special coffee
#             blend. She was so excited when she brewed her new coffee. After brewing her coffee she
#             took a sip and sighed happily.
# IMAGINED  : [INST] Susan really likes to have coffee in the morning and drinks it daily. What happened (in
#             detail)? [/INST] Susan is an individual who has developed a daily habit of enjoying a
#             cup of coffee in the morning. This routine likely begins as soon as she wakes up,
#             signifying the start of her day. Here's a detailed description of what might happen:  1.
#             Alarm goes off: The first thing Susan does in the morning is to wake up from her sleep.
#             Her alarm clock goes off, signaling the end of her night's rest. She might snooze the
# GIST-0    : Susan enjoys having coffee in the morning and drinks it daily. She went to the grocery store to buy
#             coffee and found a new brand that she had not tried before. She was excited to try it
#             and bought it. When she got home, she brewed a cup of coffee using the new brand and
#             enjoyed it very much. She was happy that she found a new coffee brand that she liked and
#             would continue to buy it.
# +1        : Susan found a new coffee shop nearby that had a special coffee blend that she really enjoyed. She
#             went there every morning to buy a cup of coffee and started her day with it. The coffee
#             shop was conveniently located, and she appreciated the friendly staff and the cozy
#             atmosphere. The coffee was rich and flavorful, and she looked forward to it every day.
#             She was happy to have found a new routine that made her mornings more enjoyable.
# +3        : Susan found a new coffee shop nearby that had a special coffee blend that she really enjoyed. She
trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# +1        : Trent's father took him to a large parking lot for driving lessons. Trent's father decided to teach
#             Trent to drive using his mother's car. Trent was nervous and made a mistake by
#             accidentally putting the car in reverse instead of drive. The car moved backward and hit
#             a curb, causing the tire to go flat. Trent's father was angry and frustrated, but
#             eventually calmed down and continued teaching Trent to drive. Trent learned to control
#             the
# +3        : Trent's father took him to a large parking lot for driving lessons. Trent's father decided to teach
#             Trent to drive using his mother's car. Trent was nervous and made several mistakes. He
#             accidentally drove the car over a curb. Trent's father became frustrated and stopped the
#             lesson. Trent's father then took him to a driving school to continue his lessons.
# FULL      : Trent's father took him to a large parking lot for driving lessons. His father's expensive car had a
#             manual transmission. Trent had difficulty learning to use the clutch and accelerator. He
#             became frustrated, and accidentally drove the car over a curb. His dad decided to teach
#             Trent to drive using his mother's car.
#
# -- CONSOLIDATION ---------------------------------------------
# Epoch 01: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and kept
#             stalling the car. His father was patient and kept encouraging him. Trent eventually got
#             the hang of it and was able to drive around the parking lot. They then went to a quieter
#             area and Trent practiced turning and parking. Trent was proud of himself and felt like
#             he had accomplished something.
# Epoch 02: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and happy to be able to drive again.
# Epoch 03: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 04: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 05: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 06: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 07: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 08: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 09: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Epoch 10: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
#
# -- FORGETTING -----------------------------------------------
# Episode 00: Trent's father took him to a large parking lot for driving lessons. Trent was nervous and had
#             trouble controlling the car. He kept stalling the car and his father became frustrated.
#             Trent's father decided to switch to an automatic transmission car, which Trent was able
#             to drive more easily. Trent was relieved and grateful for his father's patience and
#             understanding.
# Episode 01: Trent's father took him to a large parking lot for driving lessons. Trent was nervous but excited to
#             drive. He put the car in gear and started to drive. However, he accidentally hit the
#             accelerator instead of the brake pedal. The car started to move quickly, and Trent was
#             unable to stop it. They hit a large pile of rocks, and the car was damaged. Trent's
#             father was not happy and ended the driving lessons for the day
# Episode 02: Trent's father took him to a large parking lot for driving lessons. Trent was very nervous but
#             decided to listen to his father's advice. He put the car in gear and started to drive.
#             At first, he was doing poorly and had trouble controlling the car. But with his father's
#             guidance, he improved and was able to drive the car out of the parking lot. Trent was
#             relieved and grateful for the experience.
# Episode 03: Trent's father took him to a large parking lot for driving lessons. Trent had a terrible accident.
#             He lost control of the car and crashed into a ditch. Trent was scared. He didn't know
#             what to do. The car was badly damaged. Trent's father had to call the police. Trent
#             didn't get his license for a long time after that.
# Episode 04: Trent's father took him to a large parking lot for driving lessons. Trent was nervous about driving
#             on the highway. His father encouraged him to drive on the highway. Trent drove for a
#             while on the highway. He felt more confident as he continued to drive. Trent's father
#             turned off the highway and drove back to the city. Trent was relieved and grateful for
#             the experience. He had finally driven on the highway.
# Episode 05: Trent's father took him to a large parking lot for driving lessons. Trent was making the car go in
#             circles. He was practicing his turns. His father was trying to show him how to use the
#             pedals. For some reason, Trent was taking a long time to learn. Eventually, Trent was
#             able to drive the car out of the lot. Trent's father was very proud of him. It was the
#             start of a long relationship with driving.
# Episode 06: Trent's father took him to a large parking lot for driving lessons. Trent was nervous about driving
#             in traffic. His father decided it was time for him to practice. Trent put the car in
#             reverse and began to back out of the parking lot. He was reversing too quickly and the
#             car began to spin out. Trent was terrified as the car spun out of control. Luckily,
#             Trent was able to stop the car before it hit anything. Trent was shaken but unharmed. He
#             had learned an important
# Episode 07: Trent's father took him to a large parking lot for driving lessons. Trent was nervous about driving.
#             His father told him not to worry, and to just focus on the road. Trent saw a car coming
#             the other way. He hesitated, and then pulled out in front of it. The car stopped, and
#             Trent felt his heart race. Trent's father laughed and said that he was going to give the
#             other driver a scare. Trent felt embarrassed, but he learned an important
# Episode 08: Trent's father took him to a large parking lot for driving lessons. Trent got into the car and tried
#             to drive. He failed to park the car for the first time. He was very frustrated and
#             angry. But, he kept practicing and eventually improved. He was able to park the car by
#             the end of the lesson. Trent was very happy with his improvement. He wanted to continue
#             taking driving lessons.
# ======================================== STORY 3 =========================================
# ORIGINAL : Travis was driving along a road at night. He saw a woman in a white gown walking along the road.
#             Travis stopped and offered her a ride. The woman got into the car without a word. Travis
#             then informed her she couldn't smoke in the car.
# IMAGINED  : [INST] Travis was driving along a road at night. What happened (in detail)? [/INST] Travis was
#             driving along a quiet, two-lane road, the kind where the only sounds you could hear were
#             the gentle hum of his car engine and the occasional crickets chirping in the distance.
#             The moon was full and bright, casting long, dancing shadows on the pavement as he drove.
#             He had the radio turned off, preferring the silence to the static and chatter that
#             filled the airwaves.  As he drove, he kept a careful eye on the
# GIST-0    : Travis was driving along a road at night when he saw a woman in a white dress standing on the side
#             of the road. He stopped the car and offered her a ride. She got in and they started
#             talking. She told him that she had been in a car accident and her boyfriend had left her
#             there. She asked him to take her to the nearest gas station. He agreed and they drove to
#             the gas station. She got out of the car and thanked him for the ride. He
# +1        : Travis was driving along a road at night when he picked up a hitchhiker, a woman. She asked for a
#             cigarette and Travis informed her she couldn't smoke in the car. The woman then asked
#             for a ride to the next town. Travis agreed and they continued driving. The woman then
#             asked for a drink of water and Travis stopped at a gas station to get her a bottle. As
#             they were driving again, the woman asked Travis if he wanted to have
# +3        : Travis was driving along a road at night. He saw a woman in a white gown walking along the road. He
#             stopped the car and offered her a ride. She accepted and got in the car. Travis then
#             informed her she couldn't smoke in the car. She lit a cigarette and he asked her to put
#             it out. She refused and he became angry. She then asked him why he stopped for her and
#             he told her he didn't want to hit her with his car.
# FULL      : Travis was driving along a road at night. He saw a woman in a white gown walking along the road.
#             Travis stopped and offered her a ride. The woman got into the car without a word. Travis
#             then informed her she couldn't smoke in the car.
#
# -- CONSOLIDATION ---------------------------------------------
# Epoch 01: Travis was driving along a road at night. He saw a deer in the road and swerved to avoid it.
#             However, he lost control of the car and crashed into a tree. The impact was so severe
#             that the car was totaled. Travis was taken to the hospital with injuries. The deer was
#             also killed in the accident.
# Epoch 02: Travis was driving along a road at night. He saw a car in front of him with its lights off. He
#             thought the car was broken down and stopped to help. He got out of his car and
#             approached the other car. He saw a man inside the car and asked if he needed help. The
#             man said he was fine and just needed to change a tire. Travis helped him change the tire
#             and then the man gave Travis a bag of drugs and asked him to take it
# Epoch 03: Travis was driving along a road at night. He was going a little too fast and lost control of his
#             car. He hit a tree and his car was totaled. He was taken to the hospital and was lucky
#             to be alive. He had some injuries but was expected to make a full recovery. He was
#             charged with reckless driving and was required to pay a fine and do community service.
#             He was also required to attend a driver safety class. He was grateful to be alive and
#             promised
# Epoch 04: Travis was driving along a road at night. He saw a woman in a white dress standing on the side of
#             the road. He stopped his car and offered her a ride. She got in and they started
#             talking. She told him that she had been in a car accident and her boyfriend had left her
#             there. She asked him to take her to the nearest gas station. He agreed and they drove to
#             the gas station. She got out of the car and thanked him for the 
#             baby was still alive, and he had a bruise on his head. Travis felt so sad that he
#             couldn't stop in time. He took the baby to the hospital, and the baby was going to be
#             okay. Travis was so relieved
# Episode 08: Travis was driving along a road at night. He saw a baby animal trying to cross the road. He got out
#             of his car and picked it up. He then tried to find the mother. He ended up keeping the
#             baby animal. He was surprised by how soft it was. He drove home with the baby animal. He
#             was told it was a young rabbit. He kept it as a pet. He noticed it grew quickly. He
#             eventually found a new home for it. He
# ======================================== STORY 4 =========================================
# ORIGINAL : The log floated on the river. A man tried to sit on it. It rolled over. The man tried to get back on
#             it. The log kept spinning in the man's grip.
# IMAGINED  : [INST] The log floated on the river. What happened (in detail)? [/INST] To provide a detailed answer
#             to your question, I would need more context. Here's a possible scenario based on the
#             given information:  A log, which is a large, heavy piece of wood, was floating on a
#             river. The log could have ended up in the river from various sources. It might have been
#             carried away by the river current after falling from the bank during heavy rain or
#             flooding. Alternatively, it could have been deliberately placed in the river by someone
#             for various reasons
# GIST-0    : The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and sat
# +1        : The man sat on the log, but it floated away, and he fell into the water. The man tried to grab the
#             log again, but it floated away again. The man tried to swim after the log, but it
#             floated too fast. The man gave up and watched the log float away.
# +3        : The man tried to sit on the log, but it kept spinning in his grip. He tried to hold on, but the log
#             rolled over, and he fell in the water.
# FULL      : The log floated on the river. A man tried to sit on it. It rolled over. The man tried to get back on
#             it. The log kept spinning in the man's grip.
#
# -- CONSOLIDATION ---------------------------------------------
# Epoch 01: The log floated on the river. The log was hit by a rock and the rock broke the log in half. The log
#             floated away in two pieces.
# Epoch 02: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a boat, but the
#             log was too big. The man gave up and sat down on the riverbank. The log floated away.
# Epoch 03: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a hook, but the log was too far away. The
#             man tried to grab
# Epoch 04: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man gave up and sat down on the riverbank to rest.
# Epoch 05: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             tried to grab
# Epoch 06: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
# Epoch 07: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
# Epoch 08: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
# Epoch 09: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
# Epoch 10: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
#
# -- FORGETTING -----------------------------------------------
# Episode 00: The log floated on the river. The man tried to grab it with a stick, but the log rolled away. The
#             man tried to grab it with his hands, but the log was too slippery. The man tried to grab
#             it with a rope, but the log was too heavy. The man tried to grab it with a net, but the
#             log was too big. The man tried to grab it with a boat, but the log was too fast. The man
#             gave up and
# Episode 01: The log floated on the river. They tried to keep it from floating away. They used a net to catch it.
#             They put it in the back of their pickup truck. They took it home and put it in their
#             pond. They were happy to have their log back.
# Episode 02: The log floated on the river. The man put the log on the shore. The log was heavy. The man was
#             tired. He took a break. The log was too big for him to move by himself. He needed help.
#             He called for his friend. His friend helped him move the log. The log was moved from the
#             river.
# Episode 03: The log floated on the river. The man grabbed the log with his hands. He pulled the log onto the
#             shore. The man dragged the log with him. He carried the log to his car. The man put the
#             log in his car. He drove to his friend's house. The man's friend helped him carry the
#             log into his house. The man's friend split the log. He gave a piece to the man. The man
#             took the piece home to his wife
# Episode 04: The log floated on the river. The man grabbed the log with his hands. He pulled the log onto the
#             shore. The man dragged the log into the woods. He hid the log under some bushes. The man
#             kept the log for 20 years. He used it to make a beautiful furniture. The man sold the
#             furniture for 1000 dollars. He kept the 1000 dollars. He used it to pay off his debts.
#             He went camping in the woods
# Episode 05: The log floated on the river. The man put the log on the truck. The log was too heavy for the man to
#             put in the truck by himself. So he asked his neighbor for help. The neighbor helped the
#             man get the log in the truck. The log was so heavy that the truck broke down trying to
#             move it. The log had to be left behind.
# Episode 06: The log floated on the river. The man put the log on the shore. The log was soaked. The man rolled
#             the log in the river. The log floated again. The man was soaked as well. The man had to
#             start over again. The man was angry. The man threw the log back in the river. The man
#             had to retrieve it again. The man was soaked and frustrated. The man decided to leave
#             the log in the river. The man had
# Episode 07: The log floated on the river. The man tried to grab it. But the water was too strong. The log hit
#             the man, knocking him in the water. The man swam to the log and grabbed it. He was so
#             tired he could barely swim back to shore. But he made it, and secured the log on the
#             shore.
# Episode 08: The log floated on the river. The man tried to grab it. But it slipped out of his hands. He fell
#             into the water. And he lost his hold on the log. He was unable to hold on long enough to
#             get it. He eventually tired and swam back to shore. He was very tired but eventually
#             held the log. He managed to hold on this time. He was then able to pull the log onto the
#             shore. He had to exert a lot of effort but was
#
# Done. Total stories printed: 500

# %%
import pickle, random
from pathlib import Path
import textwrap

DATA_DIR = Path("output/data")

# load all the necessary pickles
stories_data = pickle.load(open(DATA_DIR/"recalled_stories.pkl", "rb"))
con_data     = pickle.load(open(DATA_DIR/"consolidation_recall.pkl", "rb"))
forg_path    = (DATA_DIR/"forgetting_multi.pkl"
                if (DATA_DIR/"forgetting_multi.pkl").exists()
                else DATA_DIR/"forgetting.pkl")
forg_data    = pickle.load(open(forg_path, "rb"))

# choose one story index (or hard-code e.g. idx = 0)
n = len(stories_data["recalled_stories"]["full"])
idx = random.randrange(n)

# extract texts
orig        = stories_data["recalled_stories"]["full"][idx]
encoded0    = stories_data["recalled_stories"][0][idx]

# consolidation recalls:
# epoch_recalls is a list of lists: [ [stories@epoch1], [stories@epoch2], … ]
con_epochs  = con_data["epoch_recalls"]
con_early   = con_epochs[0][idx]
con_late    = con_epochs[-1][idx]

# forgetting recalls:
# "recalls" is a list of episodes: [baseline, ep1, ep2, …]
forg_recs   = forg_data["recalls"]
if forg_recs and isinstance(forg_recs[0], str):
    forg_recs = [forg_recs]       # wrap legacy single‐episode form
# pick first real episode as “early”
early_i     = 1 if len(forg_recs) > 1 else 0
late_i      = len(forg_recs) - 1
forg_early  = forg_recs[early_i][idx]
forg_late   = forg_recs[late_i][idx]

# simple LaTeX-escaping for underscores & ampersands
def esc(s):
    return (s.replace("\\", "\\textbackslash{}")
             .replace("_", "\\_")
             .replace("&", "\\&")
             .replace("%", "\\%"))

# wrap long text into paragraphs so your table cells don’t overflow
wrap = lambda txt: textwrap.fill(esc(txt), 60, subsequent_indent="")

col_width = "p{0.15\\linewidth}"
fmt = "|" + "|".join([col_width]*6) + "|"

print(r"\begin{table}[ht]")
print(r"\footnotesize")
print(r"\centering")
print(r"\renewcommand{\arraystretch}{1.3}")
print(r"\begin{tabular}{" + fmt + "}")
print(r"\hline")
print(r"\textbf{Original} & "
      r"\textbf{Encoded (0-detail)} & "
      r"\textbf{Cons. (early)} & "
      r"\textbf{Cons. (late)} & "
      r"\textbf{Forget (early)} & "
      r"\textbf{Forget (late)} \\ \hline")
print(f"{wrap(orig)} &")
print(f"{wrap(encoded0)} &")
print(f"{wrap(con_early)} &")
print(f"{wrap(con_late)} &")
print(f"{wrap(forg_early)} &")
print(f"{wrap(forg_late)} \\\\ \\hline")
print(r"\end{tabular}")
print(r"\caption[One‐story consolidation & forgetting]{"
      r"Text trajectories for one randomly selected story: original, "
      r"0‐detail encoding, early vs late consolidation, and early vs late forgetting.}")
print(r"\label{table:one_story_traj}")
print(r"\end{table}")
# Out:
# \begin{table}[ht]
# \footnotesize
# \centering
# \renewcommand{\arraystretch}{1.3}
# \begin{tabular}{|p{0.15\linewidth}|p{0.15\linewidth}|p{0.15\linewidth}|p{0.15\linewidth}|p{0.15\linewidth}|p{0.15\linewidth}|}
# \hline
# \textbf{Original} & \textbf{Encoded (0-detail)} & \textbf{Cons. (early)} & \textbf{Cons. (late)} & \textbf{Forget (early)} & \textbf{Forget (late)} \\ \hline
# I had never played a board game before. My son asked me to
# buy some. We bought candy land, because it looked simple. We
# sat down and played it. I enjoyed the game immensely. &
# I had never played a board game before. I was at a friend's
# house and they had a bunch of board games. They asked me if
# I wanted to play one and I said sure. They showed me a game
# called "Candyland" and explained the rules to me. It was a
# simple game where you roll a dice and move your character
# along the board to the next color. I was immediately hooked.
# I had so much fun playing that game that I wanted to play
# more &
# I had never played a board game before. I was at a friend's
# house and they had a board game called "Candyland." They
# explained the rules to me and we all played it together. I
# enjoyed it and we played it a few more times that night. I
# was surprised at how much fun I had and how easy it was to
# learn. I was also impressed by how well the game was
# designed and how it brought us all together. I left their
# house feeling happy and &
# I had never played a board game before. I was at a friend's
# house and they had a bunch of board games. They asked me if
# I wanted to play one and I said sure. They showed me a game
# called "Candyland" and explained the rules to me. It was a
# simple game where you roll a dice and move your character
# along the board to the next color. I was immediately hooked.
# I had so much fun playing that game that I wanted to play &
# I had never played a board game before. I was at a friend's
# house for dinner. After dinner, we decided to play a board
# game. They had me choose one. I picked one called
# "Candyland." They told me that they had never played it
# before either. We all worked together to figure out the
# rules. It was a fun game! I was glad I picked Candyland.
# After the game, we all agreed that it was a good choice. We
# had &
# I had never played a board game before. I was at a friend's
# house. They invited me to play a game of Monopoly. I had
# never played before. I got lucky and won the game. Since
# then I've been playing board games. I now like them. \\ \hline
# \end{tabular}
# \caption[One‐story consolidation & forgetting]{Text trajectories for one randomly selected story: original, 0‐detail encoding, early vs late consolidation, and early vs late forgetting.}
# \label{table:one_story_traj}
# \end{table}
